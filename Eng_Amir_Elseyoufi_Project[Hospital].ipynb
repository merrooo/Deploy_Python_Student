# %%
class Patient:
   def __init__ (self,name,gender,age):
    self.Name=name
    self.Gender=gender
    self.Age=age
   def Pdetails(self):
     Patientdf={'Visitor':['Name','Gender','Age',],'data':[self.Name,self.Gender,self.Age]}
     return f'Name: [{self.Name}]   Gender : [{self.Gender}]   Age : [{self.Age}]Years Old'
     import pandas as pd
     Patients=pd.DataFrame(Patientdf)
     Patients.to_excel(r'C:\Users\pc\Downloads\Patient.xlsx',excel_writer, sheet_name='Sheet1', index=False)
def Pinputs():
 print('\t\t|--------------------------|\t\t')
 Px1=input('\t\tEnter Name\t\t')
 print('\t\t--------------------------|\t\t')
 Px2=input('\t\tEnter Gender\t\t')
 print('\t\t---------------------------\t\t')
 Px3=input('\t\tEnter Age\t\t')
 print('\t\t---------------------------\t\t')
 print('\t     Patient Successfully Recorded As\t\t')
 print('\t\t---------------------------\t\t')
 y=Patient(Px1,Px2,Px3)
 Patientdf=print({y.Pdetails()})
 Ask()
#  ------------------------------------------------------------------------------------------------------------------------------------------------------------
class Doctor:
   def __init__ (self,name,specializing,salary,age,phone):
    self.Name=name
    self.Specializing=specializing
    self.Salary=salary
    self.Age=age
    self.Phone=phone
   def Ddetails(self):
     Doctordf={'Doctor':['Name','Specializing','Salary','Age','Phone'],'Data':[self.Name,self.Specializing,self.Salary,self.Age,self.Phone]}
     return f'Name: [{self.Name}]  Specializing: [{self.Specializing}]  Salary: [{self.Salary}]  Age: [{self.Age}]  Phone: [{self.Phone}]'
     import pandas as pd
     Doctors=pd.DataFrame(Doctordf)
     Doctors.to_excel(r'C:\Users\pc\Downloads\Doctors.xlsx', index=False)
def Dinputs():
 print('\t\t|--------------------------|\t\t')
 Dx1=input('\t\tEnter Name             ')
 print('\t\t--------------------------\t\t')
 Dx2=input('\t\tEnter Specializing     ')
 print('\t\t--------------------------\t\t')
 Dx3=input('\t\tEnter Salary           ')
 print('\t\t--------------------------\t\t')
 Dx4=input('\t\tEnter Age              ')
 print('\t\t--------------------------\t\t')
 Dx5=input('\t\tEnter Phone            ')
 print('\t\t--------------------------\t\t')
 print('\t        Doctor Successfully Recorded\t\t')
 print('\t\t---------------------------\t\t')
 y=Doctor(Dx1,Dx2,Dx3,Dx4,Dx5)
 Doctordf=print({y.Ddetails()})
 Ask()
 #  ------------------------------------------------------------------------------------------------------------------------------------------------------------
class Hospital:
   def __init__ (self,name,location,worker):
    self.Name=name
    self.Location=location
    self.Worker=worker
   def Hdetails(self):
     Hospitaldf={'Hospital':['Name','Location','Worker',],'Data':[self.Name,self.Location,self.Worker]}
     return f'Name: [{self.Name}]  Location: [{self.Location}]  Worker: [{self.Worker}]'
     import pandas as pd
     Hospitals=pd.DataFrame(Hospitaldf)
     Hospitals.to_excel(r'C:\Users\pc\Downloads\Hospital.xlsx', index=False)
def Hinputs():
 print('\t\t|--------------------------|\t\t')
 Hx1=input('\t\tEnter Name             ')
 print('\t\t--------------------------\t\t')
 Hx2=input('\t\tEnter Location         ')
 print('\t\t--------------------------\t\t')
 Hx3=input('\t\tEnter Worker           ')
 print('\t\t--------------------------\t\t')
 print('\t       Hospital Successfully Recorded\t\t')
 print('\t\t--------------------------\t\t')
 y=Hospital(Hx1,Hx2,Hx3)
 Hospitaldf=print({y.Hdetails()})
 Ask()
#  ------------------------------------------------------------------------------------------------------------------------------------------------------------
class Appointment:
   def __init__ (self,doctor,patient,date):
    self.Doctor=doctor
    self.Patient=patient
    self.Date=date
   def Adetails(self):
     Appointmentdf={'Patient':['Doctor','Patient','Date',],'Data':[self.Doctor,self.Patient,self.Date]}
     return f'Doctor: [{self.Doctor}]  Patient: [{self.Patient}]  Date: [{self.Date}]'
     import pandas as pd
     Appointments=pd.DataFrame(Appointmentdf)
     Appointments.to_excel(r'C:\Users\pc\Downloads\Appointment.xlsx', index=False)
def Ainputs():
   print('\t\t|--------------------------|\t\t')
   Ax1=input('\t\tEnter Doctor           ')
   print('\t\t--------------------------\t\t')
   Ax2=input('\t\tEnter Patient          ')
   print('\t\t--------------------------\t\t')
   Ax3=input('\t\tEnter Date             ')
   print('\t\t--------------------------\t\t')
   print('\t       Appointment Successfully Recorded\t\t')
   print('\t\t--------------------------\t\t')
   y=Appointment(Ax1,Ax2,Ax3)
   Appointmentdf=print({y.Adetails()})
   Ask()
#  ------------------------------------------------------------------------------------------------------------------------------------------------------------
def Ask():
    print('\t\t|--------------------------|\t\t')
    print('\t\t|--------------------------|\t\t')
    z=(input('\tFor [ADD-Patient] Press[1]-For [ADD-Doctor] Press[2]-For [ADD-Hospital] Press[3]-For [ADD-Worker] Press[4]-[Exit] Press Any Key'))
    if z =='1':
     Pinputs()
    elif z=='2' :
     Dinputs()
    elif z=='3' :
     Hinputs()
    elif z=='4' :
     Ainputs()
    else:
     print('\t\t----------THANKS----------\t\t')
     exit()
Ask()
